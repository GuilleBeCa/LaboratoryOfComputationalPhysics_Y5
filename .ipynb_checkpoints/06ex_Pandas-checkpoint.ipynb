# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
# !wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/
# Out:
# --2022-12-12 12:06:54--  https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18, 2620:100:6025:18::a27d:4512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/xvjzaxzz3ysphme/data_000637.txt [following]
# --2022-12-12 12:06:54--  https://www.dropbox.com/s/raw/xvjzaxzz3ysphme/data_000637.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4299e885677f236e08f5879a6c.dl.dropboxusercontent.com/cd/0/inline/ByfW1A5biuGJF9RE6wdgnUk7Q6rPd3NucgRjuCey5Ak1wrV6Qlpa9WCjS2haxrdepqBZdbgszr_8leGAo2shGpBfkNAuKwm3NiyPBS2J-kf04XbMc4fjyGJmQKnFqhaAQAC4O3DQ7zmliQxp_cPRftVfNm92qyEVFCc2_tVpH6wluA/file# [following]
# ...

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.
#
# 2\. Find out the number of BX in a ORBIT (the value 'x').
#
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.
#
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
#
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.
#
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('/home/guillermo/data/data_000637.txt.2') as f:
    data_tot=pd.read_csv(f)

# %%
N=np.random.randint(10000,len(data_tot))
data=data_tot[:N]
data
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0          1     0          123  3869200167        2374        26
# 1          1     0          124  3869200167        2374        27
# 2          1     0           63  3869200167        2553        28
# 3          1     0           64  3869200167        2558        19
# 4          1     0           64  3869200167        2760        25
# ...      ...   ...          ...         ...         ...       ...
# 254662     1     0           47  3869202700        2640        18
# 254663     1     0          139  3869202700        2649         0
# 254664     1     0           45  3869202700        2646        10
# 254665     1     0           46  3869202700        2647        29
# 254666     1     0           43  3869202700        2770        10
#
# [254667 rows x 6 columns]

# %%
#long way
data_0=data.loc[data['BX_COUNTER']==0].index
x_value=np.max(data.loc[data_0-1]['BX_COUNTER'])

# %%
#short way
x_value=np.max(data['BX_COUNTER'])

# %%
x_value
# Out:
# 3563

# %%
time_tot=data_tot.tail(1).values[0][3:]-data_tot.head(1).values[0][3:]
time_passed=(time_tot[0]*x_value+sum(time_tot[1:]))*25*10**(-9)
time_passed  #in seconds
# Out:
# 0.9801408

# %%
time=(data['ORBIT_CNT']*x_value+data['BX_COUNTER']+data['TDC_MEAS'])
data_2=pd.concat([data,time],axis=1)
data_2=data_2.rename(columns={0:'TIME'})
data_2
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0          1     0          123  3869200167        2374        26
# 1          1     0          124  3869200167        2374        27
# 2          1     0           63  3869200167        2553        28
# 3          1     0           64  3869200167        2558        19
# 4          1     0           64  3869200167        2760        25
# ...      ...   ...          ...         ...         ...       ...
# 254662     1     0           47  3869202700        2640        18
# 254663     1     0          139  3869202700        2649         0
# 254664     1     0           45  3869202700        2646        10
# 254665     1     0           46  3869202700        2647        29
# 254666     1     0           43  3869202700        2770        10
#
#                   TIME
# 0       13785960197421
# 1       13785960197422
# 2       13785960197602
# 3       13785960197598
# 4       13785960197806
# ...                ...
# ...

# %%
data_3=data_2.copy()
data_3['HEAD']=np.random.randint(0,2,len(data_2))
data_3
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0          1     0          123  3869200167        2374        26
# 1          0     0          124  3869200167        2374        27
# 2          0     0           63  3869200167        2553        28
# 3          1     0           64  3869200167        2558        19
# 4          1     0           64  3869200167        2760        25
# ...      ...   ...          ...         ...         ...       ...
# 254662     0     0           47  3869202700        2640        18
# 254663     1     0          139  3869202700        2649         0
# 254664     1     0           45  3869202700        2646        10
# 254665     0     0           46  3869202700        2647        29
# 254666     0     0           43  3869202700        2770        10
#
#                   TIME
# 0       13785960197421
# 1       13785960197422
# 2       13785960197602
# 3       13785960197598
# 4       13785960197806
# ...                ...
# ...

# %%
data_4=data_3[data_3['HEAD']==1]
data_4
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0          1     0          123  3869200167        2374        26
# 3          1     0           64  3869200167        2558        19
# 4          1     0           64  3869200167        2760        25
# 6          1     0           61  3869200167        2772        14
# 7          1     0          139  3869200167        2776         0
# ...      ...   ...          ...         ...         ...       ...
# 254656     1     1            5  3869202700        2423        26
# 254660     1     0           64  3869202700        2581         7
# 254661     1     0           48  3869202700        2638         8
# 254663     1     0          139  3869202700        2649         0
# 254664     1     0           45  3869202700        2646        10
#
#                   TIME
# 0       13785960197421
# 3       13785960197598
# 4       13785960197806
# 6       13785960197807
# 7       13785960197797
# ...                ...
# ...

# %%
plot_1=data_2[data_2['FPGA']==0]
plot_2=data_2[data_2['FPGA']==1]
fig, axs = plt.subplots(2)
axs[0].hist(plot_1['TDC_CHANNEL'])
axs[1].hist(plot_2['TDC_CHANNEL'])

axs[0].set_title('FDGA=0')
axs[1].set_title('FDGA=1')
# Out:
# Text(0.5, 1.0, 'FDGA=1')

# %%
plot_1
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0          1     0          123  3869200167        2374        26
# 1          1     0          124  3869200167        2374        27
# 2          1     0           63  3869200167        2553        28
# 3          1     0           64  3869200167        2558        19
# 4          1     0           64  3869200167        2760        25
# ...      ...   ...          ...         ...         ...       ...
# 254662     1     0           47  3869202700        2640        18
# 254663     1     0          139  3869202700        2649         0
# 254664     1     0           45  3869202700        2646        10
# 254665     1     0           46  3869202700        2647        29
# 254666     1     0           43  3869202700        2770        10
#
#                   TIME
# 0       13785960197421
# 1       13785960197422
# 2       13785960197602
# 3       13785960197598
# 4       13785960197806
# ...                ...
# ...

# %%
plot_2
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 10         1     1            7  3869200167        2785         4
# 12         1     1            6  3869200167        2792        18
# 15         1     1          139  3869200167        2797         0
# 16         1     1            8  3869200167        2787        14
# 18         1     1            5  3869200167        2795         4
# ...      ...   ...          ...         ...         ...       ...
# 254654     1     1            3  3869202700        2418        28
# 254655     1     1            8  3869202700        2420        26
# 254656     1     1            5  3869202700        2423        26
# 254657     1     1            2  3869202700        2566         9
# 254658     1     1            1  3869202700        2578         0
#
#                   TIME
# 10      13785960197810
# 12      13785960197831
# 15      13785960197818
# 16      13785960197822
# 18      13785960197820
# ...                ...
# ...
